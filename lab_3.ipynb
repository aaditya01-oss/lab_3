# %% [markdown]
# ## LAB_3

# %% [markdown]
# #### Creating Base class Employee and defining constructor with private variables and Getting methods (encapsulation) and setting methods for salary

# %%
class Employee:
    def __init__(self,emp_id,name,salary):
        self.__emp_id = emp_id
        self.__name = name
        self.__salary = salary
        
    #Getting Methods    
    def get_emp_id(self):
        return self.__emp_id
    
    def get_name(self):
        return self.__name
    
    def get_salary(self):
        return self.__salary
    
    #Settings Method
    def set_salary(self,salary):
        self.__salary = salary

# %% [markdown]
# #### Defining Child class Professor that inherites the property of Base class Employee and accessing the private variables through super() function in Child class

# %%
class Professor(Employee):
    def __init__(self,emp_id,name,salary,subject):
        super().__init__(emp_id,name,salary)
        
        self.subject = subject
        
    #Display function
    def display_details(self):
        print("Professor Details")
        print("------------------")
        print("ID:",self.get_emp_id())
        print("Name:",self.get_name())
        print("Salary:",self.get_salary())
        print("Subject:",self.subject)

# %% [markdown]
# #### Creating Object of professor(child) class

# %%
object = Professor(11,"Harry",90000,"Engineering Physics")
#Calling display function with object
object.display_details()
# Out:
# Professor Details
# ------------------
# ID: 11
# Name: Harry
# Salary: 90000
# Subject: Engineering Physics

# %% [markdown]
# #### File Handling for csv

# %%
import csv

data = [
    ['Name','Age','City'],
    ['Asha',22,'Kathmandu'],
    ['Ramesh',25,'Pokhara']
]

with open('output.csv','w',newline='') as file:
    writer = csv.writer(file)
    writer.writerows(data)

data = {
    'Name':['Asha','Ramesh'],
    'Age':[22,25],
    'City':['Kathmandu','Pokhara']
}

# %% [markdown]
# #### Using Pandas library

# %%
import pandas as pd

df = pd.DataFrame(data)
df.to_csv('output1.csv',index=False)

# %% [markdown]
# #### Reading csv files

# %%
with open('output.csv','r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age', 'City']
# ['Asha', '22', 'Kathmandu']
# ['Ramesh', '25', 'Pokhara']

# %% [markdown]
# #### Reading csv files using pandas

# %%
import pandas as pd
output = pd.read_csv('output.csv')
print(output)
# Out:
#      Name  Age       City
# 0    Asha   22  Kathmandu
# 1  Ramesh   25    Pokhara

# %% [markdown]
# #### File handing with json

# %%
import json
  
data = [
    {"Name":"Asha","Age":22},
    {"Name":"Ramesh","Age":25}
]      

with open('output.json','w') as file:
    json.dump(data,file,indent=4)

# %% [markdown]
# #### File handing with txt

# %%
students = [
    "1, Ram, 85",
    "2, Sita, 90",
    "3, Hari, 78"
]

with open("students.txt",'w') as file:
    for student in students:
        file.write(student)

# %% [markdown]
# #### Read data from txt file

# %%
with open("students.txt", "r") as file:
    content = file.read()

print("\nReading data from file:")
print(content)
# Out:
# Reading data from file:
# 1, Ram, 852, Sita, 903, Hari, 78

# %% [markdown]
# #### Creating data and write to excel

# %%
# %pip install pandas openpyxl
import pandas as pd

# Create data
data = {
    "ID": [1, 2, 3],
    "Name": ["Ram", "Sita", "Hari"],
    "Marks": [85, 90, 78]
}

df = pd.DataFrame(data)

# Write to Excel
df.to_excel("students.xlsx", index=False)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\a s u s\appdata\roaming\python\python313\site-packages (2.3.1)
# Requirement already satisfied: openpyxl in c:\users\a s u s\appdata\roaming\python\python313\site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\a s u s\appdata\roaming\python\python313\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\a s u s\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\a s u s\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\a s u s\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in c:\users\a s u s\appdata\roaming\python\python313\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\a s u s\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\A S U S\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\A S U S\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\A S U S\AppData\Roaming\Python\Python313\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #### Read excel file

# %%
import pandas as pd

df = pd.read_excel("students.xlsx")
print(df)
# Out:
#    ID  Name  Marks
# 0   1   Ram     85
# 1   2  Sita     90
# 2   3  Hari     78
